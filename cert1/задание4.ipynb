# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 1. Выполните группировку данных по столбцу 'class' и вычислите среднее значение для каждого класса по столбцу 'fare'
titanic = sns.load_dataset("titanic")
class_fare_means = titanic.groupby('class')['fare'].mean()
print("Среднее значение 'fare' для каждого класса:")
print(class_fare_means)
# Out:
# Среднее значение 'fare' для каждого класса:
# class
# First     84.154687
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64
# C:\Users\Дом\AppData\Local\Temp\ipykernel_7476\3655219480.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   class_fare_means = titanic.groupby('class')['fare'].mean()

# %%
# 2. Постройте график распределения данных по столбцу 'age'
plt.figure(figsize=(15, 6))
sns.histplot(titanic['age'], bins=80)
plt.title("Распределение данных по столбцу 'age'")
plt.xlabel("Возраст")
plt.ylabel("Частота")
plt.show()

# %%
# 3. Постройте тепловую карту корреляционной матрицы числовых переменных
numeric_cols = titanic.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = titanic[numeric_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='YlOrRd')
plt.title("Корреляционная матрица числовых переменных")
plt.show()
